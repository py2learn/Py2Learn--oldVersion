# %%
from IPython.display import Image
Image(filename='images/logo.png',width=200, height=200)

# %% [markdown]
# Py2Learn é um **curso de python** online criado através da interface **Jupyter** que chegou para mudar a tua história como programador, enriquecendo assim o teu conhecimento sobre este tipo de linguagem de programação e até mesmo agilizar a tua aprendizagem para que não deixes de sentir-te um **"nub"**.

# %% [markdown]
# Podes começar este curso clicando no link abaixo:

# %% [markdown]
# [jupyter course](Introduction.ipynb)
